# %% [markdown]
# pip install --upgrade jupyterlab jupyter_server

# %%
# !pip install --upgrade jupyterlab jupyter_server
# Out:
# zsh:1: command not found: pip

# %%
/usr/local/bin/python3.8 -m pip install --upgrade ipykernel
# Out:
#   Cell In[12], line 1
#     usr/local/bin/python3.8(-m, pip, install, --upgrade, ipykernel)
#                          ^
# SyntaxError: invalid syntax

# %%
# %%capture
pip install pandas

# %%
# import pandas as pd
