# %% [markdown]
# #meu codigo do mes passado

# %%
#esse é o codigo da aula passada no mes passado
#no dia 26 de fevereiro

# %%
#1 - Importações
#2 - Coleta dos dados da série temporal
#3 - Visualização das séries temporal
#4 - Normalização dos dados
#5 - Criação das janelas temporais
#6 - Separação treino / teste(sem embaralhar)
#7 - Construção do modelo lstm
#8 - Treinamento do modelo
#9 - Avaliação do modelo
#10 - Visualização das previsões
#11 - Previsão do próximo dia

# %%
# %%capture
# !pip install tensorflow yfinance

# %%
import numpy as np
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense , LSTM
from tensorflow.keras.callbacks import EarlyStopping

# %%
ticker = "tsla"
start_date = "2015-01-01"
end_date = None

# %%
df = yf.download(ticker, start=start_date, end=end_date)
print()
print(df.head())
print(df.tail())
# Out:
# /tmp/ipykernel_232/144919319.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start=start_date, end=end_date)
# [*********************100%***********************]  1 of 1 completed
# Price           Close       High        Low       Open    Volume
# Ticker           TSLA       TSLA       TSLA       TSLA      TSLA
# Date
# 2015-01-02  14.620667  14.883333  14.217333  14.858000  71466000
# 2015-01-05  14.006000  14.433333  13.810667  14.303333  80527500
# 2015-01-06  14.085333  14.280000  13.614000  14.004000  93928500
# 2015-01-07  14.063333  14.318667  13.985333  14.223333  44526000
# 2015-01-08  14.041333  14.253333  14.000667  14.187333  51637500
# Price            Close        High         Low        Open    Volume
# Ticker            TSLA        TSLA        TSLA        TSLA      TSLA
# Date
# 2026-03-06  396.730011  402.350006  394.209991  398.089996  64054600
# 2026-03-09  398.679993  401.589996  381.399994  390.049988  67018900
# 2026-03-10  399.239990  406.589996  398.190002  402.220001  59258700
# 2026-03-11  407.820007  416.380005  402.149994  402.279999  62559900
# 2026-03-12  395.010010  406.500000  394.649994  405.100006  59382702

# %%
series = df[['Close']].dropna()
print(series)
# Out:
# Price            Close
# Ticker            TSLA
# Date
# 2015-01-02   14.620667
# 2015-01-05   14.006000
# 2015-01-06   14.085333
# 2015-01-07   14.063333
# 2015-01-08   14.041333
# ...                ...
# 2026-03-06  396.730011
# 2026-03-09  398.679993
# 2026-03-10  399.239990
# 2026-03-11  407.820007
# 2026-03-12  395.010010
#
# [2814 rows x 1 columns]

# %%
#3 visualização dos graficos do titanic
plt.figure()
plt.plot(series)
plt.title(f"Preço de fechamento - {ticker}")
plt.xlabel("Data")
plt.ylabel("Preço")
plt.show()

# %%
#4 Normalização dos dados
scaler = MinMaxScaler(feature_range=(0,1))
series_scaled = scaler.fit_transform(series)
print(series_scaled)
# Out:
# [[0.01049895]
#  [0.0092192 ]
#  [0.00938437]
#  ...
#  [0.81128537]
#  [0.82914917]
#  [0.80247845]]

# %%
#5 Criação das janelas temporais
def create_window(data, window_size):
  X, y = [], []
  for i in range(len(data) - window_size):
    X.append(data[i:i+window_size])
    y.append(data[i+window_size])
  return np.array(X), np.array(y)

# %%
window_size = 30

X, y = create_window(series_scaled, window_size)

print(f"Formato do x: {X.shape}")
print(f"Formato do y: {y.shape}")
# Out:
# Formato do x: (2784, 30, 1)
# Formato do y: (2784, 1)

# %%
#6 Seperação treino / teste(sem embaralhar)
split = int(0.8 * len(X))

X_train, X_test = X[:split], X[split:]
y_train, y_test = y[:split], y[split:]

print(f"Treino: {X_train.shape}")
print(f"Teste: {X_test.shape}")
# Out:
# Treino: (2227, 30, 1)
# Teste: (557, 30, 1)

# %%
# 7 - construção do modelo lstm
model = Sequential()
model.add(LSTM(50, activation='tanh', input_shape=(window_size, 1)))
model.add(Dense(1))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.compile(
    optimizer="adam",
    loss='mse'
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 50)             │        10,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │            51 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 10,451 (40.82 KB)
#  Trainable params: 10,451 (40.82 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
#8 Treinamento do modelo
early_stop = EarlyStopping(
    monitor = "val_loss",
    patience = 50,
    restore_best_weights = True
)

# %%
history = model.fit (
    X_train,
    y_train,
    batch_size = 50,
    epochs = 120,
    validation_split = 0.2,
    callbacks = [early_stop],
    verbose = 2
)
# Out:
# Epoch 1/120
# 36/36 - 0s - 11ms/step - loss: 1.1997e-04 - val_loss: 4.3986e-04
# Epoch 2/120
# 36/36 - 0s - 11ms/step - loss: 1.3272e-04 - val_loss: 3.5823e-04
# Epoch 3/120
# 36/36 - 0s - 12ms/step - loss: 1.1820e-04 - val_loss: 3.9084e-04
# Epoch 4/120
# 36/36 - 1s - 18ms/step - loss: 1.1101e-04 - val_loss: 3.4844e-04
# Epoch 5/120
# 36/36 - 0s - 12ms/step - loss: 1.0567e-04 - val_loss: 3.7773e-04
# Epoch 6/120
# 36/36 - 0s - 13ms/step - loss: 1.0749e-04 - val_loss: 3.5249e-04
# Epoch 7/120
# 36/36 - 0s - 11ms/step - loss: 1.1270e-04 - val_loss: 3.5976e-04
# Epoch 8/120
# 36/36 - 0s - 11ms/step - loss: 1.0729e-04 - val_loss: 3.4683e-04
# Epoch 9/120
# 36/36 - 0s - 11ms/step - loss: 1.0498e-04 - val_loss: 4.1089e-04
# Epoch 10/120
# 36/36 - 0s - 11ms/step - loss: 1.1271e-04 - val_loss: 3.4618e-04
# Epoch 11/120
# 36/36 - 0s - 11ms/step - loss: 1.0338e-04 - val_loss: 5.5733e-04
# Epoch 12/120
# 36/36 - 0s - 11ms/step - loss: 1.1941e-04 - val_loss: 3.4175e-04
# Epoch 13/120
# 36/36 - 0s - 12ms/step - loss: 1.0943e-04 - val_loss: 3.4392e-04
# Epoch 14/120
# 36/36 - 1s - 22ms/step - loss: 1.0991e-04 - val_loss: 3.5126e-04
# Epoch 15/120
# 36/36 - 1s - 19ms/step - loss: 1.0841e-04 - val_loss: 3.5790e-04
# Epoch 16/120
# 36/36 - 1s - 16ms/step - loss: 1.0713e-04 - val_loss: 3.4087e-04
# Epoch 17/120
# 36/36 - 0s - 13ms/step - loss: 1.0574e-04 - val_loss: 3.4307e-04
# Epoch 18/120
# 36/36 - 1s - 17ms/step - loss: 1.0325e-04 - val_loss: 3.4111e-04
# Epoch 19/120
# 36/36 - 0s - 12ms/step - loss: 1.1061e-04 - val_loss: 3.3853e-04
# Epoch 20/120
# 36/36 - 0s - 12ms/step - loss: 1.0937e-04 - val_loss: 3.5345e-04
# Epoch 21/120
# 36/36 - 0s - 12ms/step - loss: 1.0659e-04 - val_loss: 3.5910e-04
# Epoch 22/120
# 36/36 - 1s - 17ms/step - loss: 1.0429e-04 - val_loss: 3.4133e-04
# Epoch 23/120
# 36/36 - 0s - 13ms/step - loss: 1.1305e-04 - val_loss: 3.4059e-04
# Epoch 24/120
# 36/36 - 1s - 16ms/step - loss: 1.0290e-04 - val_loss: 3.4176e-04
# Epoch 25/120
# 36/36 - 0s - 13ms/step - loss: 1.0216e-04 - val_loss: 3.8897e-04
# Epoch 26/120
# 36/36 - 0s - 12ms/step - loss: 1.1935e-04 - val_loss: 3.4849e-04
# Epoch 27/120
# 36/36 - 0s - 12ms/step - loss: 1.0487e-04 - val_loss: 3.3587e-04
# Epoch 28/120
# 36/36 - 0s - 11ms/step - loss: 1.0198e-04 - val_loss: 3.8108e-04
# Epoch 29/120
# 36/36 - 0s - 11ms/step - loss: 1.1699e-04 - val_loss: 3.3264e-04
# Epoch 30/120
# 36/36 - 1s - 19ms/step - loss: 1.0826e-04 - val_loss: 3.5536e-04
# Epoch 31/120
# 36/36 - 0s - 12ms/step - loss: 1.0338e-04 - val_loss: 3.7723e-04
# Epoch 32/120
# 36/36 - 0s - 13ms/step - loss: 1.0348e-04 - val_loss: 3.3143e-04
# Epoch 33/120
# 36/36 - 0s - 12ms/step - loss: 1.0984e-04 - val_loss: 4.0063e-04
# Epoch 34/120
# 36/36 - 0s - 12ms/step - loss: 1.1102e-04 - val_loss: 3.7146e-04
# Epoch 35/120
# 36/36 - 1s - 17ms/step - loss: 1.0424e-04 - val_loss: 3.4090e-04
# Epoch 36/120
# 36/36 - 0s - 14ms/step - loss: 1.1539e-04 - val_loss: 4.0104e-04
# Epoch 37/120
# 36/36 - 1s - 21ms/step - loss: 1.0428e-04 - val_loss: 3.3082e-04
# Epoch 38/120
# 36/36 - 1s - 30ms/step - loss: 1.0969e-04 - val_loss: 3.3768e-04
# Epoch 39/120
# 36/36 - 0s - 11ms/step - loss: 1.0637e-04 - val_loss: 3.3162e-04
# Epoch 40/120
# 36/36 - 0s - 12ms/step - loss: 1.1463e-04 - val_loss: 4.4401e-04
# Epoch 41/120
# 36/36 - 1s - 15ms/step - loss: 1.0444e-04 - val_loss: 3.3657e-04
# Epoch 42/120
# 36/36 - 0s - 11ms/step - loss: 1.0096e-04 - val_loss: 4.0103e-04
# Epoch 43/120
# 36/36 - 0s - 11ms/step - loss: 1.1119e-04 - val_loss: 3.3874e-04
# Epoch 44/120
# 36/36 - 0s - 11ms/step - loss: 1.0018e-04 - val_loss: 3.8478e-04
# Epoch 45/120
# 36/36 - 0s - 11ms/step - loss: 1.0757e-04 - val_loss: 3.4699e-04
# Epoch 46/120
# 36/36 - 0s - 13ms/step - loss: 1.0918e-04 - val_loss: 3.3180e-04
# Epoch 47/120
# 36/36 - 0s - 12ms/step - loss: 1.0710e-04 - val_loss: 3.2864e-04
# Epoch 48/120
# 36/36 - 0s - 13ms/step - loss: 1.0228e-04 - val_loss: 3.3251e-04
# Epoch 49/120
# 36/36 - 0s - 12ms/step - loss: 1.0348e-04 - val_loss: 3.4833e-04
# Epoch 50/120
# 36/36 - 0s - 13ms/step - loss: 9.9420e-05 - val_loss: 3.6171e-04
# Epoch 51/120
# 36/36 - 0s - 12ms/step - loss: 1.0598e-04 - val_loss: 3.3149e-04
# Epoch 52/120
# 36/36 - 1s - 17ms/step - loss: 1.0455e-04 - val_loss: 3.3834e-04
# Epoch 53/120
# 36/36 - 1s - 17ms/step - loss: 1.1306e-04 - val_loss: 4.1711e-04
# Epoch 54/120
# 36/36 - 0s - 12ms/step - loss: 1.0564e-04 - val_loss: 3.3200e-04
# Epoch 55/120
# 36/36 - 0s - 12ms/step - loss: 1.0631e-04 - val_loss: 3.3203e-04
# Epoch 56/120
# 36/36 - 0s - 12ms/step - loss: 1.0356e-04 - val_loss: 3.3147e-04
# Epoch 57/120
# 36/36 - 0s - 11ms/step - loss: 1.0218e-04 - val_loss: 3.2768e-04
# Epoch 58/120
# 36/36 - 0s - 10ms/step - loss: 1.0165e-04 - val_loss: 3.5080e-04
# Epoch 59/120
# 36/36 - 0s - 12ms/step - loss: 1.0070e-04 - val_loss: 3.8067e-04
# Epoch 60/120
# 36/36 - 1s - 14ms/step - loss: 1.0118e-04 - val_loss: 3.3029e-04
# Epoch 61/120
# 36/36 - 1s - 22ms/step - loss: 1.0174e-04 - val_loss: 3.2898e-04
# Epoch 62/120
# 36/36 - 0s - 12ms/step - loss: 1.0447e-04 - val_loss: 3.2743e-04
# Epoch 63/120
# 36/36 - 0s - 11ms/step - loss: 1.1017e-04 - val_loss: 3.2778e-04
# Epoch 64/120
# 36/36 - 0s - 10ms/step - loss: 1.0335e-04 - val_loss: 3.2949e-04
# Epoch 65/120
# 36/36 - 0s - 10ms/step - loss: 1.1085e-04 - val_loss: 3.3472e-04
# Epoch 66/120
# 36/36 - 0s - 11ms/step - loss: 1.0630e-04 - val_loss: 4.2581e-04
# Epoch 67/120
# 36/36 - 0s - 11ms/step - loss: 1.0982e-04 - val_loss: 3.3290e-04
# Epoch 68/120
# 36/36 - 0s - 11ms/step - loss: 1.0444e-04 - val_loss: 3.2814e-04
# Epoch 69/120
# 36/36 - 0s - 12ms/step - loss: 9.9005e-05 - val_loss: 3.4588e-04
# Epoch 70/120
# 36/36 - 0s - 11ms/step - loss: 1.0585e-04 - val_loss: 3.4890e-04
# Epoch 71/120
# 36/36 - 0s - 12ms/step - loss: 1.0047e-04 - val_loss: 3.2730e-04
# Epoch 72/120
# 36/36 - 1s - 18ms/step - loss: 1.0459e-04 - val_loss: 3.5493e-04
# Epoch 73/120
# 36/36 - 0s - 13ms/step - loss: 1.0380e-04 - val_loss: 3.2785e-04
# Epoch 74/120
# 36/36 - 0s - 12ms/step - loss: 1.0169e-04 - val_loss: 3.7814e-04
# Epoch 75/120
# 36/36 - 0s - 12ms/step - loss: 1.1206e-04 - val_loss: 3.4000e-04
# Epoch 76/120
# 36/36 - 0s - 11ms/step - loss: 1.1029e-04 - val_loss: 3.7527e-04
# Epoch 77/120
# 36/36 - 0s - 10ms/step - loss: 1.0297e-04 - val_loss: 3.3730e-04
# Epoch 78/120
# 36/36 - 0s - 11ms/step - loss: 1.0588e-04 - val_loss: 3.2791e-04
# Epoch 79/120
# 36/36 - 0s - 10ms/step - loss: 1.0037e-04 - val_loss: 4.2993e-04
# Epoch 80/120
# 36/36 - 0s - 11ms/step - loss: 1.0669e-04 - val_loss: 3.4121e-04
# Epoch 81/120
# 36/36 - 0s - 10ms/step - loss: 1.0108e-04 - val_loss: 3.3157e-04
# Epoch 82/120
# 36/36 - 0s - 11ms/step - loss: 1.0269e-04 - val_loss: 3.2764e-04
# Epoch 83/120
# 36/36 - 0s - 10ms/step - loss: 9.9176e-05 - val_loss: 3.2982e-04
# Epoch 84/120
# 36/36 - 0s - 10ms/step - loss: 9.9589e-05 - val_loss: 3.5776e-04
# Epoch 85/120
# 36/36 - 0s - 11ms/step - loss: 1.0318e-04 - val_loss: 3.2762e-04
# Epoch 86/120
# 36/36 - 1s - 14ms/step - loss: 9.9743e-05 - val_loss: 4.7258e-04
# Epoch 87/120
# 36/36 - 1s - 15ms/step - loss: 1.0929e-04 - val_loss: 3.4091e-04
# Epoch 88/120
# 36/36 - 1s - 18ms/step - loss: 1.0316e-04 - val_loss: 3.2754e-04
# Epoch 89/120
# 36/36 - 0s - 11ms/step - loss: 1.0382e-04 - val_loss: 3.2737e-04
# Epoch 90/120
# 36/36 - 0s - 11ms/step - loss: 9.9540e-05 - val_loss: 3.5838e-04
# Epoch 91/120
# 36/36 - 1s - 17ms/step - loss: 1.0164e-04 - val_loss: 3.3100e-04
# Epoch 92/120
# 36/36 - 0s - 13ms/step - loss: 1.0700e-04 - val_loss: 4.0621e-04
# Epoch 93/120
# 36/36 - 1s - 16ms/step - loss: 1.1444e-04 - val_loss: 3.7770e-04
# Epoch 94/120
# 36/36 - 1s - 18ms/step - loss: 1.0450e-04 - val_loss: 3.4510e-04
# Epoch 95/120
# 36/36 - 0s - 12ms/step - loss: 1.0296e-04 - val_loss: 3.3998e-04
# Epoch 96/120
# 36/36 - 0s - 11ms/step - loss: 1.0682e-04 - val_loss: 4.7544e-04
# Epoch 97/120
# 36/36 - 1s - 17ms/step - loss: 1.0072e-04 - val_loss: 3.4318e-04
# Epoch 98/120
# 36/36 - 0s - 12ms/step - loss: 1.0058e-04 - val_loss: 3.7872e-04
# Epoch 99/120
# 36/36 - 0s - 12ms/step - loss: 1.0042e-04 - val_loss: 3.2657e-04
# Epoch 100/120
# 36/36 - 1s - 18ms/step - loss: 9.8484e-05 - val_loss: 3.2920e-04
# Epoch 101/120
# 36/36 - 0s - 13ms/step - loss: 9.9227e-05 - val_loss: 3.2897e-04
# Epoch 102/120
# 36/36 - 1s - 17ms/step - loss: 1.0163e-04 - val_loss: 4.1813e-04
# Epoch 103/120
# 36/36 - 0s - 11ms/step - loss: 1.1097e-04 - val_loss: 3.3282e-04
# Epoch 104/120
# 36/36 - 0s - 11ms/step - loss: 1.0146e-04 - val_loss: 4.4102e-04
# Epoch 105/120
# 36/36 - 0s - 10ms/step - loss: 1.0293e-04 - val_loss: 3.2806e-04
# Epoch 106/120
# 36/36 - 0s - 10ms/step - loss: 9.7537e-05 - val_loss: 3.8977e-04
# Epoch 107/120
# 36/36 - 0s - 11ms/step - loss: 1.1418e-04 - val_loss: 3.3993e-04
# Epoch 108/120
# 36/36 - 1s - 17ms/step - loss: 1.0637e-04 - val_loss: 3.2775e-04
# Epoch 109/120
# 36/36 - 0s - 14ms/step - loss: 1.0189e-04 - val_loss: 3.2966e-04
# Epoch 110/120
# 36/36 - 1s - 14ms/step - loss: 1.1125e-04 - val_loss: 3.2911e-04
# Epoch 111/120
# 36/36 - 1s - 19ms/step - loss: 1.0136e-04 - val_loss: 3.5063e-04
# Epoch 112/120
# 36/36 - 0s - 13ms/step - loss: 1.0470e-04 - val_loss: 3.3251e-04
# Epoch 113/120
# 36/36 - 0s - 11ms/step - loss: 1.0604e-04 - val_loss: 3.3613e-04
# Epoch 114/120
# 36/36 - 0s - 11ms/step - loss: 1.0167e-04 - val_loss: 3.5009e-04
# Epoch 115/120
# 36/36 - 0s - 11ms/step - loss: 1.0025e-04 - val_loss: 3.4334e-04
# Epoch 116/120
# 36/36 - 0s - 11ms/step - loss: 1.0360e-04 - val_loss: 5.0313e-04
# Epoch 117/120
# 36/36 - 0s - 11ms/step - loss: 1.0510e-04 - val_loss: 3.3621e-04
# Epoch 118/120
# 36/36 - 0s - 11ms/step - loss: 1.0317e-04 - val_loss: 3.2881e-04
# Epoch 119/120
# 36/36 - 0s - 10ms/step - loss: 9.8778e-05 - val_loss: 3.4418e-04
# Epoch 120/120
# 36/36 - 0s - 10ms/step - loss: 1.0002e-04 - val_loss: 3.9422e-04

# %%
# 9. avaliação do modelo
y_pred = model.predict(X_test)

y_test_inv = scaler.inverse_transform(y_test)
y_pred_inv = scaler.inverse_transform(y_pred)

rmse = np.sqrt(mean_squared_error(y_test_inv, y_pred_inv))
print(f"RMSE: {rmse}")
# Out:
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# RMSE: 12.714700487290562

# %%
# 10. Visualização das previsões
plt.figure()
plt.plot(series.index[-len(y_test):] , y_test_inv, label="Valor real")
plt.plot(series.index[-len(y_test):], y_pred_inv, label="Valor previsto")
plt.title(f"Previsão de preço de fechamento - {ticker} com LSTM")
plt.xlabel("Data")
plt.ylabel("Preço")
plt.legend()
plt.show()

# %%
#11. Previsão de fechamento do próximo dia
last_window = series_scaled[-window_size:]
last_window = last_window.reshape(1, window_size, 1)

next_day_pred = model.predict(last_window) # valores entre 0 e 1
next_day_price = scaler.inverse_transform(next_day_pred) # valores previsto em dólares

print(f"Previão de preço da {ticker} para o proximo dia $ {next_day_price[0][0]:.2f}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Previão de preço da tsla para o proximo dia $ 390.53
